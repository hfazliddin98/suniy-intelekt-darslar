# %%
import numpy as np
import pandas as pd
from pandas import Series

# %%
cars_dict = {'Malibu':15000,'nexia3':10000,'Lacetti':20000,'Mazda':13000} # list malumot turi

# %%
type(cars_dict)
# Out:
# dict

# %%
cars1 = Series(cars_dict) # Series malumot turiga o`tkazish uchun

# %%
cars1
# Out:
# Malibu     15000
# nexia3     10000
# Lacetti    20000
# Mazda      13000
# dtype: int64

# %%
type(cars1)
# Out:
# pandas.core.series.Series

# %%
cars2 = Series({'Malibu':15000,'Nexia3':10000,'Lacetti':20000,'Mazda':13000}) # Series malumot turiga o`tkazish list malumot turini

# %%
cars2
# Out:
# Malibu     15000
# nexia3     10000
# Lacetti    20000
# Mazda      13000
# dtype: int64

# %%
'Malibu' in cars2 # 'Malibu' qiymati cars2 da borligini tekshirish uchun ishlatiladi
# Out:
# True

# %%
models = ['Malibu', 'BMW', 'Nexia3', 'Lacetti', 'Mazda']

# %%
cars3 = Series(cars2, index=models) # index boyicha tartiblash uchun ishlatiladi bolmaganlari uchun NAN bo`lib qoladi yani qiymat yo`q manosida

# %%
cars3
# Out:
# Malibu     15000.0
# BMW            NaN
# Nexia3     10000.0
# Lacetti    20000.0
# Mazda      13000.0
# dtype: float64
