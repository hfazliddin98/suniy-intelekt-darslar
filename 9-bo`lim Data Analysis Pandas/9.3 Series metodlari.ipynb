# %%
import pandas as pd
import numpy as np
from pandas import Series

# %%
cars = Series({'Malibu':25000,'Nexia3':24000,'Mazda':25000,'BMW':45000})

# %%
models = ['Malibu','Lacetti', 'Nexia3', 'Mazda', 'BMW']

# %%
cars2 = Series(cars, index=models)

# %%
cars2
# Out:
# Malibu     25000.0
# Lacetti        NaN
# Nexia3     24000.0
# Mazda      25000.0
# BMW        45000.0
# dtype: float64

# %%
cars2.isnull() # Series malumot turida  yo`qligini aniqlash uchun qo`llaniladi
# Out:
# Malibu     False
# Lacetti     True
# Nexia3     False
# Mazda      False
# BMW        False
# dtype: bool

# %%
cars2.notnull() # Series malumot turda borlarini bilish uchun qollaniladi
# Out:
# Malibu      True
# Lacetti    False
# Nexia3      True
# Mazda       True
# BMW         True
# dtype: bool

# %%
cars3 =Series({'Malibu':25000,'Nexia3':24000,'Mazda':25000,'BMW':45000})

# %%
cars2 + cars3 # Armetik ammalarni bajarish uchun ishlatiladi
# Out:
# BMW        90000.0
# Lacetti        NaN
# Malibu     50000.0
# Mazda      50000.0
# Nexia3     48000.0
# dtype: float64

# %%
cars2.name = 'Avtosalon'

# %%
cars2.index.name = 'modellar'

# %%
cars2
# Out:
# modellar
# Malibu     25000.0
# Lacetti        NaN
# Nexia3     24000.0
# Mazda      25000.0
# BMW        45000.0
# Name: Avtosalon, dtype: float64

# %%
cars2.index
# Out:
# Index(['Malibu', 'Lacetti', 'Nexia3', 'Mazda', 'BMW'], dtype='object', name='modellar')

# %%
cars2.values # Qiymatlarini korish
# Out:
# array([25000.,    nan, 24000., 25000., 45000.])

# %% [markdown]
# uyga vazifa

# %%
cars2.hasnans # NAN qiymatlar bor (True) yo`qligi (False)
# Out:
# True

# %%
cars2.dtype # Qiymatning malumot turini ko`rsatadi
# Out:
# dtype('float64')

# %%
cars2.is_unique # Qiymatlar takrorlanmasligini tekshrish
# Out:
# False

# %%
cars2.shape # Series hajmi
# Out:
# (5,)

# %%
cars2.size # Series hajmi
# Out:
# 5

# %%
cars2.iloc[2] # malumotlarga index boyicha murojat qilish
# Out:
# 24000.0

# %%
cars2.iloc[-1]
# Out:
# 45000.0

# %%
cars2['Malibu'] # malumotni indexsi nomi bo`yicha qidirish
# Out:
# 25000.0

# %%
cars2.loc['Malibu'] # malumotni indexsi nomi boyicha qidirish
# Out:
# 25000.0

# %%
cars2.max() # max qiymatini topish uchun
# Out:
# 45000.0

# %%
cars2.min() # min qiymatini topish uchun
# Out:
# 24000.0

# %%
cars2.mean() # O`rtacha qiymatini topish uchun
# Out:
# 29750.0
