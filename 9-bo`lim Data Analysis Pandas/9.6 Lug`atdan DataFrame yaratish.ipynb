# %%
import pandas as pd
from pandas import Series

# %%
data = {
    'Uzbekiston':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:15.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
df = pd.DataFrame(data) # Lug`atdan DataFrame yaratish uchun ishlatiladi

# %%
df
# Out:
#       Uzbekiston  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        15.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df.index.name = 'Yil' # Indexlariga nom kiritish

# %%
df
# Out:
#       Uzbekiston  Kazakhstan
# Yil
# 2021        33.9        18.9
# 2020        33.5        15.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df = pd.DataFrame(data, index=[2021,2020, 2018]) # kerakli indexlar boyicha saralab olish

# %%
df
# Out:
#       Uzbekiston  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        15.7
# 2018        32.5        18.3

# %%
df.T # ustunlarni qatorga aylantirish uchun ishlatiladi
# Out:
#             2021  2020  2018
# Uzbekiston  33.9  33.5  32.5
# Kazakhstan  18.9  15.7  18.3

# %%
df.values # qiymatlarni array korinishiga otkazish yoki ajratib olish
# Out:
# array([[33.9, 18.9],
#        [33.5, 15.7],
#        [32.5, 18.3]])

# %%
df.index
# Out:
# Int64Index([2021, 2020, 2018], dtype='int64')

# %%
index = df.index

# %%
index
# Out:
# Int64Index([2021, 2020, 2018], dtype='int64')

# %%
type(index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
index[0]
# Out:
# 2021

# %%
index[:5]
# Out:
# Int64Index([2021, 2020, 2018], dtype='int64')

# %%
index[0] = 22 # index qiymatlarini ozgartirib bolmaydi
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-68c2c38963a8> in <module>
# ----> 1 index[0] = 22 # index qiymatlarini ozgartirib bolmaydi
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4583     @final
#    4584     def __setitem__(self, key, value):
# -> 4585         raise TypeError("Index does not support mutable operations")
#    4586
#    4587     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
df

# %%
df = pd.DataFrame(data)

# %%
df

# %%
df.columns # kalonnalarini korish uchun ishlatiladi

# %%
'AQSH' in df.columns # kolonnalar ichidan borligini tekshirish uchun ishlatiladi

# %%
2021 in df.index # indexlar ichida borligini tekshirish uchun ishlatiladi
