# %%
import pandas as pd

# %%
usernames = {'anvar':'anvarbek223', 'olim':'olimtoy', 'maryam':'mary334455','javohir':'javohir445'}
emails = {'anvar':'anvar@gmail.com', 'olim':'olim@mail.ru','maryam':'mary33@gmail.com','javohir':'javohir445@gmail.com'}

data = {
    'username':usernames,
    'email':emails
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com

# %%
df.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir'], dtype='object')

# %%
data2 ={
    'username':{'olim':'olimjon21','mayram':'mayram2020'},
    'email':{'olim':'olimjon21@gmail.com','mayram':'mayram20@gmail.com'}
}

# %%
df2 =df.append(pd.DataFrame(data2)) # DataFramelarni bir biriga qo`shish

# %%
df2
# Out:
#             username                 email
# anvar    anvarbek223       anvar@gmail.com
# olim         olimtoy          olim@mail.ru
# maryam    mary334455      mary33@gmail.com
# javohir   javohir445  javohir445@gmail.com
# olim       olimjon21   olimjon21@gmail.com
# mayram    mayram2020    mayram20@gmail.com

# %%
df2.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir', 'olim', 'mayram'], dtype='object')

# %%
newid =pd.Index(['olim','mariyam','hamida']) # Pandasning Idex fuksiyasi orqali Yangi DataFrame yaratish uchun ishlatiladi

# %%
newid
# Out:
# Index(['olim', 'mariyam', 'hamida'], dtype='object')

# %%
newid.isin(df2.index) # ikkita DataFrame inexlarini bir biri ichidan borligini tekshirish uchun ishlatiladi
# Out:
# array([ True, False, False])

# %%
df2.index.difference(newid) # ikkita DataFrame farqini korsatadi
# Out:
# Index(['anvar', 'javohir', 'maryam', 'mayram'], dtype='object')

# %%
newid.difference(df2.index)
# Out:
# Index(['hamida', 'mariyam'], dtype='object')

# %%
df2.index.union(newid) # ikkala DataFramni jamlash uchun ishatiladi
# Out:
# Index(['anvar', 'hamida', 'javohir', 'mariyam', 'maryam', 'mayram', 'olim',
#        'olim'],
#       dtype='object')

# %%
df2.index
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir', 'olim', 'mayram'], dtype='object')

# %%
df2.index.delete(0) # index nomeri boyicha ochirib tashlash
# Out:
# Index(['olim', 'maryam', 'javohir', 'olim', 'mayram'], dtype='object')

# %%
df2.index.drop('mayram') # nomi boyicha ochirib tashlash ikkita bolsa ohiridan ochradi
# Out:
# Index(['anvar', 'olim', 'maryam', 'javohir', 'olim'], dtype='object')
