# %%
import pandas as pd
import numpy as np

# %%
data = {
    'yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'aholi soni':[33.9,33.5,32.9,32.5,31.9,31.5,30.9,28.5],
    'temp':[1.54,1.45,1.56,1.23,1.52,1.35,1.46,1.34],
    'zichlik':[79.77,78.21,78.32,76.21,78.12,79.54,78.98,79.24]
}
df = pd.DataFrame(data)
df
# Out:
#     yil  aholi soni  temp  zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.45    78.21
# 2  2019        32.9  1.56    78.32
# 3  2018        32.5  1.23    76.21
# 4  2017        31.9  1.52    78.12
# 5  2016        31.5  1.35    79.54
# 6  2015        30.9  1.46    78.98
# 7  2010        28.5  1.34    79.24

# %%
df['yil'] # Series malumot turini qataryapti
# Out:
# 0    2021
# 1    2020
# 2    2019
# 3    2018
# 4    2017
# 5    2016
# 6    2015
# 7    2010
# Name: yil, dtype: int64

# %%
df[['yil']] # DataFrame malumot turini qaytaradi
# Out:
#     yil
# 0  2021
# 1  2020
# 2  2019
# 3  2018
# 4  2017
# 5  2016
# 6  2015
# 7  2010

# %%
df['yil'].to_numpy() # numpyga otkazish
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2010])

# %%
df[3:] # kerakli indexlar oralig`ini ajratib olish
# Out:
#     yil  aholi soni  temp  zichlik
# 3  2018        32.5  1.23    76.21
# 4  2017        31.9  1.52    78.12
# 5  2016        31.5  1.35    79.54
# 6  2015        30.9  1.46    78.98
# 7  2010        28.5  1.34    79.24

# %%
df[['yil']][df['yil']>2018] # DataFramni filterlash va kerakli qiymatni olish uchun ishlatiladi
# Out:
#     yil
# 0  2021
# 1  2020
# 2  2019

# %%
df2 = df.transpose(copy=True) # DataFramni ustunlari va qatorlarini almashtirish uchun ishlatiladi
df2
# Out:
#                   0        1        2        3        4        5        6  \
# yil         2021.00  2020.00  2019.00  2018.00  2017.00  2016.00  2015.00
# aholi soni    33.90    33.50    32.90    32.50    31.90    31.50    30.90
# temp           1.54     1.45     1.56     1.23     1.52     1.35     1.46
# zichlik       79.77    78.21    78.32    76.21    78.12    79.54    78.98
#
#                   7
# yil         2010.00
# aholi soni    28.50
# temp           1.34
# zichlik       79.24
