# %% [markdown]
# Indexlash qator(ustun) tanlash filtirlash

# %%
import pandas as pd 
import numpy as np

# %%
data = {
    'yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'aholi soni':[33.9,33.5,32.9,32.5,31.9,31.5,30.9,28.5],
    'temp':[1.54,1.45,1.56,1.23,1.52,1.35,1.46,1.34],
    'zichlik':[79.77,78.21,78.32,76.21,78.12,79.54,78.98,79.24]
}
df = pd.DataFrame(data)
df
# Out:
#     yil  aholi soni  temp  zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.45    78.21
# 2  2019        32.9  1.56    78.32
# 3  2018        32.5  1.23    76.21
# 4  2017        31.9  1.52    78.12
# 5  2016        31.5  1.35    79.54
# 6  2015        30.9  1.46    78.98
# 7  2010        28.5  1.34    79.24

# %%
data = df['aholi soni'] # DataFrameni ustunini serice malumot turiga aylantib olish
data
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.5
# 6    30.9
# 7    28.5
# Name: aholi soni, dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data = df[['aholi soni']] # DataFramedan ihtiyoriy ustunini ajratib olish
data
# Out:
#    aholi soni
# 0        33.9
# 1        33.5
# 2        32.9
# 3        32.5
# 4        31.9
# 5        31.5
# 6        30.9
# 7        28.5

# %%
data = df['aholi soni']
data
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.5
# 6    30.9
# 7    28.5
# Name: aholi soni, dtype: float64

# %%
data[2] # Serice malumot turidan numpy malumot turiga otkazish index boyicha
type(data[2])
# Out:
# 32.9

# %%
 data[[2]] # index boyich serice malumot turini ajratib olish
 type(data)
# Out:
# pandas.core.series.Series

# %%
data
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# 4    31.9
# 5    31.5
# 6    30.9
# 7    28.5
# Name: aholi soni, dtype: float64

# %%
data[0:4] # indexlar boyicha ajratib olish
# Out:
# 0    33.9
# 1    33.5
# 2    32.9
# 3    32.5
# Name: aholi soni, dtype: float64

# %%
data[[1,2,4,5,7]]  # indexlar boyicha ajratib olish
# Out:
# 1    33.5
# 2    32.9
# 4    31.9
# 5    31.5
# 7    28.5
# Name: aholi soni, dtype: float64

# %%
obj = pd.Series(np.arange(8), index=('a','b','c','d','e','f','g','h')) # aniq indexlar boyicha series malumot turini yaratish
obj
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64

# %%
obj[0:4] # indexlar boyicha ajratib olish
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
obj['b':'d'] # index nomlari boyicha ajratib olish
# Out:
# b    1
# c    2
# d    3
# dtype: int64

# %%
obj[[1,5]] # tartib raqami boyicha ajratib olish
# Out:
# b    1
# f    5
# dtype: int64

# %%
obj['a':'c']=20 # indexlari boyicha biron qiymatga tenglab qoyish

# %%
obj
# Out:
# a    20
# b    20
# c    20
# d     3
# e     4
# f     5
# g     6
# h     7
# dtype: int64

# %%
obj[obj<14] # filtrlab olish uchun ishlatiladi
# Out:
# d    3
# e    4
# f    5
# g    6
# h    7
# dtype: int64
