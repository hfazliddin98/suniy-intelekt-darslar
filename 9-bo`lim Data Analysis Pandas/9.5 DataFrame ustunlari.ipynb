# %%
import pandas as pd
from pandas import Series

# %%
data = {
    'Yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'Aholi soni':[33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
    'Temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53]
}

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'Jami']) # nomlarini o`rnini o`zgartirish uchun ishlatiladi

# %%
df.head(3)
# Out:
#     Yil  Temp  Aholi soni Jami
# 0  2021  1.54        33.9  NaN
# 1  2020  1.48        33.5  NaN
# 2  2019  1.56        32.9  NaN

# %%
df = pd.DataFrame(data, columns=['Yil', 'Temp', 'Aholi soni', 'Jami'], index=[21,20,19,18,17,16,15,10]) # indexlarni o`zimiz hohlaganday qo`yish uchun

# %%
df
# Out:
#      Yil  Temp  Aholi soni Jami
# 21  2021  1.54        33.9  NaN
# 20  2020  1.48        33.5  NaN
# 19  2019  1.56        32.9  NaN
# 18  2018  1.62        32.5  NaN
# 17  2017  1.65        31.9  NaN
# 16  2016  1.66        31.4  NaN
# 15  2015  1.64        30.9  NaN
# 10  2010  1.53        28.5  NaN

# %%
df['Aholi soni'] # malum bir ustunni ajratib olish uchun ishlatiladi
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
aholi =df['Aholi soni']

# %%
aholi
# Out:
# 21    33.9
# 20    33.5
# 19    32.9
# 18    32.5
# 17    31.9
# 16    31.4
# 15    30.9
# 10    28.5
# Name: Aholi soni, dtype: float64

# %%
df.Temp # ustun nomi bo`yicha saralab olish
# Out:
# 21    1.54
# 20    1.48
# 19    1.56
# 18    1.62
# 17    1.65
# 16    1.66
# 15    1.64
# 10    1.53
# Name: Temp, dtype: float64

# %%
df.shape
# Out:
# (8, 4)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
val = pd.Series([1700,1500, 1300], index=[21,19,10]) # Series malumot turini yaratish

# %%
df.Jami = val # DataFrame malumot turiga yangi Series malumot turini qo`shish

# %%
df
# Out:
#      Yil  Temp  Aholi soni    Jami
# 21  2021  1.54        33.9  1700.0
# 20  2020  1.48        33.5     NaN
# 19  2019  1.56        32.9  1500.0
# 18  2018  1.62        32.5     NaN
# 17  2017  1.65        31.9     NaN
# 16  2016  1.66        31.4     NaN
# 15  2015  1.64        30.9     NaN
# 10  2010  1.53        28.5  1300.0

# %%
val = [1700,1600,1500,1400,1300,1200,1100,1000] 
df['Jami'] = val # DataFrame malumot turiga yangi qiymatalar qoshish

# %%
df['1500+'] = df.Jami>1500 # Jami ustunidagi malumotlar ichidan 1500 dan kattalarini ajratib olish uchun va 1500+ ustunini yaratish uchun ishlatiladi

# %%
df
# Out:
#      Yil  Temp  Aholi soni  Jami  1500+
# 21  2021  1.54        33.9  1700   True
# 20  2020  1.48        33.5  1600   True
# 19  2019  1.56        32.9  1500  False
# 18  2018  1.62        32.5  1400  False
# 17  2017  1.65        31.9  1300  False
# 16  2016  1.66        31.4  1200  False
# 15  2015  1.64        30.9  1100  False
# 10  2010  1.53        28.5  1000  False

# %%
del df['1500+'] # 1500+ ustunini o`chirib tashlash uchun ishlatiladi

# %%
df
# Out:
#      Yil  Temp  Aholi soni  Jami
# 21  2021  1.54        33.9  1700
# 20  2020  1.48        33.5  1600
# 19  2019  1.56        32.9  1500
# 18  2018  1.62        32.5  1400
# 17  2017  1.65        31.9  1300
# 16  2016  1.66        31.4  1200
# 15  2015  1.64        30.9  1100
# 10  2010  1.53        28.5  1000
