# %%
import pandas as pd
import numpy as np
import openpyxl

# %%
# df = pd.read_csv('fayllar/flight.csv', index_col=0, nrows=23)
df = pd.read_excel('fayllar/chipta.xlsx')
df
# Out:
#    Travel  Time  Unnamed: 2 Number of  Stoppage   Ticket prize(Doller)
# 0       51h 15m         NaN              2 Stops                  1156  \
# 1       57h 25m         NaN              2 Stops                  1156
# 2        26h 5m         NaN               1 Stop                  1175
# 3       21h 15m         NaN               1 Stop                  1264
# 4       22h 35m         NaN               1 Stop                  1283
# 5       21h 15m         NaN               1 Stop                  1297
# 6       27h 15m         NaN               1 Stop                  1313
# 7       35h 50m         NaN               1 Stop                  1313
# 8       27h 15m         NaN               1 Stop                  1376
# 9        27h 0m         NaN               1 Stop                  1431
# 10      43h 50m         NaN               1 Stop                  1435
# 11      38h 45m         NaN               1 Stop                  1441
# ...

# %%
df.to_csv('fayllar/chipta.csv') # jadvalni yangi faylaga yozish

# %%
df.to_excel('fayllar/chipta.xlsx', index=False) # indexlarini tashlab yuborish uchun ishlatiladi

# %%
# df.to_excel('fayllar/chipta1.xlsx', index=False, columns=['Airline name']) # falga kerakli ustunni saqlab olish ucun ishlatiladi ustun nomi uzilmagan boshi kerak

# %%
pd.read_excel('fayllar/chipta.xlsx')
# Out:
#    Travel  Time  Unnamed: 2 Number of  Stoppage   Ticket prize(Doller)
# 0       51h 15m         NaN              2 Stops                  1156  \
# 1       57h 25m         NaN              2 Stops                  1156
# 2        26h 5m         NaN               1 Stop                  1175
# 3       21h 15m         NaN               1 Stop                  1264
# 4       22h 35m         NaN               1 Stop                  1283
# 5       21h 15m         NaN               1 Stop                  1297
# 6       27h 15m         NaN               1 Stop                  1313
# 7       35h 50m         NaN               1 Stop                  1313
# 8       27h 15m         NaN               1 Stop                  1376
# 9        27h 0m         NaN               1 Stop                  1431
# 10      43h 50m         NaN               1 Stop                  1435
# 11      38h 45m         NaN               1 Stop                  1441
# ...

# %%
df
