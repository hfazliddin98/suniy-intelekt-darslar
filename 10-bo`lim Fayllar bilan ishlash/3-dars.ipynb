# %% [markdown]
# HDF5 format

# %%
import pandas as pd
import numpy as np
import openpyxl
import tables

# %%
df = pd.read_excel('fayllar/yonalish.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-21828a3f15dd> in <cell line: 1>()
# ----> 1 df = pd.read_excel('fayllar/yonalish.xlsx')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df = pd.read_csv('fayllar/chipta.csv')
df2 = pd.read_excel('fayllar/chipta.xlsx')

# %%
hdfobj = pd.HDFStore('fayllar/data.h5') # HDF5 formatidagi fayl yartilyapti

# %%
hdfobj.put('chipta', df) # HDF5 dataga key(qiymat datadan kelib chiqqan holatda) v DataFrame qoshilyapti
# Out:
# C:\Users\hatam\AppData\Local\Temp\ipykernel_16916\2219927063.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Airline name ', 'Travel  Time', 'Number of  Stoppage ',
#        'Depreture  Airport', 'Depreture Time', '1st Stoppage Waiting Hour',
#        '1st Stoppage', '2nd StoppageWaiting Time', '2nd Stoppage',
#        'Destination Airport', 'Arrival Time', 'Arrival Date'],
#       dtype='object')]
#
#   hdfobj.put('chipta', df) # HDF5 dataga key(qiymat datadan kelib chiqqan holatda) v DataFrame qoshilyapti

# %%
hdfobj.put('cipta2', df2)
# Out:
# C:\Users\hatam\AppData\Local\Temp\ipykernel_16916\703732056.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Travel  Time', 'Number of  Stoppage ', 'Depreture  Airport',
#        'Depreture Time', '1st Stoppage Waiting Hour', '1st Stoppage',
#        '2nd StoppageWaiting Time', '2nd Stoppage', 'Destination Airport',
#        'Arrival Time', 'Arrival Date'],
#       dtype='object')]
#
#   hdfobj.put('cipta2', df2)

# %%
hdfobj.keys() # HDF5 dataning kalitlarini korish uchun ishlatiladi
# Out:
# ['/chipta', '/cipta2']

# %%
hdfobj['chipta'] # HDF5 data qiymatlarini korish uchun ishlatiladi
# Out:
#    Airline name  Travel  Time  Unnamed: 2 Number of  Stoppage
# 0       Emirates      51h 15m         NaN              2 Stops  \
# 1       Emirates      57h 25m         NaN              2 Stops
# 2        Turkish       26h 5m         NaN               1 Stop
# 3         Kuwait      21h 15m         NaN               1 Stop
# 4         Etihad      22h 35m         NaN               1 Stop
# 5        Turkish      21h 15m         NaN               1 Stop
# 6       Emirates      27h 15m         NaN               1 Stop
# 7       Emirates      35h 50m         NaN               1 Stop
# 8       Multiple      27h 15m         NaN               1 Stop
# 9          Qatar       27h 0m         NaN               1 Stop
# 10         Qatar      43h 50m         NaN               1 Stop
# 11       Turkish      38h 45m         NaN               1 Stop
# 12      Emirates      22h 45m         NaN               1 Stop
# 13       British      27h 35m         NaN              2 Stops
# ...

# %%
hdfobj.close() # faylni yopish uchun ishlatiladi
