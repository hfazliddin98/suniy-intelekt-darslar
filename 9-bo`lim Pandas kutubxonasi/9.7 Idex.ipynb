# %%
import pandas as pd

# %%
data = {
    'Yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'Aholi soni':[33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
    'Temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.index # DataFramening indexlarini ko`rish uchun
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.columns # DataFramening ustunlar nomini ko`rish uchun ishlatiladi
# Out:
# Index(['Yil', 'Aholi soni', 'Temp'], dtype='object')

# %%
indeks = df.columns

# %%
'Yil' in indeks # Indexlar ichida bormi yoqligini tekshirish uchun ishlatiladi
# Out:
# True

# %%
df.T
# Out:
#                   0        1        2        3        4        5        6  \
# Yil         2021.00  2020.00  2019.00  2018.00  2017.00  2016.00  2015.00
# Aholi soni    33.90    33.50    32.90    32.50    31.90    31.40    30.90
# Temp           1.54     1.48     1.56     1.62     1.65     1.66     1.64
#
#                   7
# Yil         2010.00
# Aholi soni    28.50
# Temp           1.53

# %%
df2 = df.T # Qatorlarni ustunga aylantirish uchun ishlatiladi

# %%
df2
# Out:
#                   0        1        2        3        4        5        6  \
# Yil         2021.00  2020.00  2019.00  2018.00  2017.00  2016.00  2015.00
# Aholi soni    33.90    33.50    32.90    32.50    31.90    31.40    30.90
# Temp           1.54     1.48     1.56     1.62     1.65     1.66     1.64
#
#                   7
# Yil         2010.00
# Aholi soni    28.50
# Temp           1.53

# %%
df2.index
# Out:
# Index(['Yil', 'Aholi soni', 'Temp'], dtype='object')

# %%
'Yil' in df2.index # Indexlar ichida borligini tekshirish uchun ishlatiladi
# Out:
# True

# %%
indeks
# Out:
# Index(['Yil', 'Aholi soni', 'Temp'], dtype='object')

# %%
indeks[0] # Index nomerlari boyicha ajratib olish
# Out:
# 'Yil'

# %%
indeks[:2]
# Out:
# Index(['Yil', 'Aholi soni'], dtype='object')
