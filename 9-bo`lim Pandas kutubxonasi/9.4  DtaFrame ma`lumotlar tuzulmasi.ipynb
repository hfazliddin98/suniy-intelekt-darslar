# %%
import pandas as pd

# %%
data = {
    'Yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'Aholi soni':[33.9,33.5,32.9,32.5,31.9,31.4,30.9,28.5],
    'Temp':[1.54,1.48,1.56,1.62,1.65,1.66,1.64,1.53]
}

# %%
df = pd.DataFrame(data) # list malumot turini DataFramega o`tkazadi

# %%
df
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53

# %%
df.head() # yuqoridan faqat 5 tasi korinadi
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65

# %%
df.head # asosiy korinishi
# Out:
# <bound method NDFrame.head of     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66
# 6  2015        30.9  1.64
# 7  2010        28.5  1.53>

# %%
df.head(6) #yuqoridan faqat head(n) ta elementni korish uchun
# Out:
#     Yil  Aholi soni  Temp
# 0  2021        33.9  1.54
# 1  2020        33.5  1.48
# 2  2019        32.9  1.56
# 3  2018        32.5  1.62
# 4  2017        31.9  1.65
# 5  2016        31.4  1.66

# %%
df.shape # nechtaga nechchi massiv ekanligini korishimiz munkun
# Out:
# (8, 3)

# %%
arr= df.values

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (8, 3)
