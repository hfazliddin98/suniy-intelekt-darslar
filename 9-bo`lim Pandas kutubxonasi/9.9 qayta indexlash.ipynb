# %%
import pandas as pd
import numpy as np

# %%
data = {
    'yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'aholi soni':[33.9,33.5,32.9,32.5,31.9,31.5,30.9,28.5],
    'temp':[1.54,1.45,1.56,1.23,1.52,1.35,1.46,1.34],
    'zichlik':[79.77,78.21,78.32,76.21,78.12,79.54,78.98,79.24]
}
df = pd.DataFrame(data)
df
# Out:
#     yil  aholi soni  temp  zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.45    78.21
# 2  2019        32.9  1.56    78.32
# 3  2018        32.5  1.23    76.21
# 4  2017        31.9  1.52    78.12
# 5  2016        31.5  1.35    79.54
# 6  2015        30.9  1.46    78.98
# 7  2010        28.5  1.34    79.24

# %%
df.index = [21,20,19,18,17,16,15,10]

# %%
df
# Out:
#      yil  aholi soni  temp  zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.45    78.21
# 19  2019        32.9  1.56    78.32
# 18  2018        32.5  1.23    76.21
# 17  2017        31.9  1.52    78.12
# 16  2016        31.5  1.35    79.54
# 15  2015        30.9  1.46    78.98
# 10  2010        28.5  1.34    79.24

# %%
ind = [21,20,19,18,17,16,15,10]
ind.sort() # sonlarni tartiblash uchun ishlatiladi kichikdan kattaga qarab
ind
# Out:
# [10, 15, 16, 17, 18, 19, 20, 21]

# %%
df.reindex(ind) # DataFramni indexlar boyicha tartiblab beradi tartiblangan royhat asosida
# Out:
#      yil  aholi soni  temp  zichlik
# 10  2010        28.5  1.34    79.24
# 15  2015        30.9  1.46    78.98
# 16  2016        31.5  1.35    79.54
# 17  2017        31.9  1.52    78.12
# 18  2018        32.5  1.23    76.21
# 19  2019        32.9  1.56    78.32
# 20  2020        33.5  1.45    78.21
# 21  2021        33.9  1.54    79.77

# %%
df.reindex([10,15,20]) # DataFramdan kerakli index boyicha ajratib olish
# Out:
#      yil  aholi soni  temp  zichlik
# 10  2010        28.5  1.34    79.24
# 15  2015        30.9  1.46    78.98
# 20  2020        33.5  1.45    78.21

# %%
df.reindex(index = range(10,22), method='ffill') # indexlarini 10dan 22 gacha tolditib qiymatalriga boshidagi qiymatlarni kiritadi
# Out:
#      yil  aholi soni  temp  zichlik
# 10  2010        28.5  1.34    79.24
# 11  2015        30.9  1.46    78.98
# 12  2015        30.9  1.46    78.98
# 13  2015        30.9  1.46    78.98
# 14  2015        30.9  1.46    78.98
# 15  2015        30.9  1.46    78.98
# 16  2016        31.5  1.35    79.54
# 17  2017        31.9  1.52    78.12
# 18  2018        32.5  1.23    76.21
# 19  2019        32.9  1.56    78.32
# 20  2020        33.5  1.45    78.21
# 21  2021        33.9  1.54    79.77

# %%
df
# Out:
#      yil  aholi soni  temp  zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.45    78.21
# 19  2019        32.9  1.56    78.32
# 18  2018        32.5  1.23    76.21
# 17  2017        31.9  1.52    78.12
# 16  2016        31.5  1.35    79.54
# 15  2015        30.9  1.46    78.98
# 10  2010        28.5  1.34    79.24

# %%
df2 = df.reindex(columns=['aholi soni', 'temp', 'zichlik']) # kerakli usyunlarni qoldirish uchun ishlatiladi

# %%
df2.head() # 5ta qiymatni qaytaradi boshidan 
df2.sample() # bitta tasodifiy qiymatni qaytaradi
df2.sample(3) # uchta tasodifiy qiymat qaytaradi
# Out:
#     aholi soni  temp  zichlik
# 19        32.9  1.56    78.32
# 21        33.9  1.54    79.77
# 10        28.5  1.34    79.24
