# %%
import pandas as pd
import numpy as np

# %%
from pandas import Series # Series malumotlar tuzilmasini chaqirib olish

# %%
obj = Series([4,6,54,12])

# %%
type(obj)
# Out:
# pandas.core.series.Series

# %%
print(obj)
# Out:
# 0     4
# 1     6
# 2    54
# 3    12
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  6, 54, 12])

# %%
obj.keys
# Out:
# <bound method Series.keys of 0     4
# 1     6
# 2    54
# 3    12
# dtype: int64>

# %%
obj2= Series([7,5,6,9], index=['a','b','c','d']) # series malumot turiga indexlar qoshish siz hohlagan usulda

# %%
obj2.keys
# Out:
# <bound method Series.keys of a    7
# b    5
# c    6
# d    9
# dtype: int64>

# %%
obj2.values
# Out:
# array([7, 5, 6, 9])

# %%
obj2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
obj2[obj2>2]
# Out:
# a    7
# b    5
# c    6
# d    9
# dtype: int64

# %%
obj2[obj2<6]
# Out:
# b    5
# dtype: int64

# %%
obj2*2
# Out:
# a    14
# b    10
# c    12
# d    18
# dtype: int64

# %%
np.exp(obj2)
# Out:
# a    1096.633158
# b     148.413159
# c     403.428793
# d    8103.083928
# dtype: float64

# %%
obj2+5

# %%
obj
# Out:
# 0     4
# 1     6
# 2    54
# 3    12
# dtype: int64

# %%
obj.keys
# Out:
# <bound method Series.keys of 0     4
# 1     6
# 2    54
# 3    12
# dtype: int64>
