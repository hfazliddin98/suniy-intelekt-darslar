# %%
import pandas as pd 
import numpy as np

# %%
data = {
    'yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'aholi soni':[33.9,33.5,32.9,32.5,31.9,31.5,30.9,28.5],
    'temp':[1.54,1.45,1.56,1.23,1.52,1.35,1.46,1.34],
    'zichlik':[79.77,78.21,78.32,76.21,78.12,79.54,78.98,79.24]
}
df = pd.DataFrame(data)
df
# Out:
#     yil  aholi soni  temp  zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.45    78.21
# 2  2019        32.9  1.56    78.32
# 3  2018        32.5  1.23    76.21
# 4  2017        31.9  1.52    78.12
# 5  2016        31.5  1.35    79.54
# 6  2015        30.9  1.46    78.98
# 7  2010        28.5  1.34    79.24

# %%
df.index = [21,20,19,18,17,16,15,10]

# %%
df
# Out:
#      yil  aholi soni  temp  zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.45    78.21
# 19  2019        32.9  1.56    78.32
# 18  2018        32.5  1.23    76.21
# 17  2017        31.9  1.52    78.12
# 16  2016        31.5  1.35    79.54
# 15  2015        30.9  1.46    78.98
# 10  2010        28.5  1.34    79.24

# %%
df.drop(10, axis=0) # qator indexsi boyicha tashlab yuborish uchun ishlatiladi
# Out:
#      yil  aholi soni  temp  zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.45    78.21
# 19  2019        32.9  1.56    78.32
# 18  2018        32.5  1.23    76.21
# 17  2017        31.9  1.52    78.12
# 16  2016        31.5  1.35    79.54
# 15  2015        30.9  1.46    78.98

# %%
df.drop([17,19], axis=0) # bir nechta qatorlerni tashlab yuborish uchun ishlatiladi
# Out:
#      yil  aholi soni  temp  zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.45    78.21
# 18  2018        32.5  1.23    76.21
# 16  2016        31.5  1.35    79.54
# 15  2015        30.9  1.46    78.98
# 10  2010        28.5  1.34    79.24

# %%
df.drop('yil', axis=1) # ustunlar boyicha tashlab yuboriladi
# Out:
#     aholi soni  temp  zichlik
# 21        33.9  1.54    79.77
# 20        33.5  1.45    78.21
# 19        32.9  1.56    78.32
# 18        32.5  1.23    76.21
# 17        31.9  1.52    78.12
# 16        31.5  1.35    79.54
# 15        30.9  1.46    78.98
# 10        28.5  1.34    79.24

# %%
df3 = df.drop('yil', axis=1)

# %%
df3
# Out:
#     aholi soni  temp  zichlik
# 21        33.9  1.54    79.77
# 20        33.5  1.45    78.21
# 19        32.9  1.56    78.32
# 18        32.5  1.23    76.21
# 17        31.9  1.52    78.12
# 16        31.5  1.35    79.54
# 15        30.9  1.46    78.98
# 10        28.5  1.34    79.24

# %%
df3.drop('temp', axis=1, inplace=True) # kiritilgan ozgarish asosiy bolib qolishi uchun

# %%
df3
# Out:
#     aholi soni  zichlik
# 21        33.9    79.77
# 20        33.5    78.21
# 19        32.9    78.32
# 18        32.5    76.21
# 17        31.9    78.12
# 16        31.5    79.54
# 15        30.9    78.98
# 10        28.5    79.24

# %%
df.drop([10,16], axis=0, inplace=True) # kiritilgan ozgarish asosiy bolib qolishi uchun

# %%
df
# Out:
#      yil  aholi soni  temp  zichlik
# 21  2021        33.9  1.54    79.77
# 20  2020        33.5  1.45    78.21
# 19  2019        32.9  1.56    78.32
# 18  2018        32.5  1.23    76.21
# 17  2017        31.9  1.52    78.12
# 15  2015        30.9  1.46    78.98
