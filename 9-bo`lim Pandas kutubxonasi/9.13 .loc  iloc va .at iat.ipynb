# %%
import pandas as pd
import numpy as np

# %%
data = {
    'yil':[2021,2020,2019,2018,2017,2016,2015,2010],
    'aholi soni':[33.9,33.5,32.9,32.5,31.9,31.5,30.9,28.5],
    'temp':[1.54,1.45,1.56,1.23,1.52,1.35,1.46,1.34],
    'zichlik':[79.77,78.21,78.32,76.21,78.12,79.54,78.98,79.24]
}
df = pd.DataFrame(data)
df
# Out:
#     yil  aholi soni  temp  zichlik
# 0  2021        33.9  1.54    79.77
# 1  2020        33.5  1.45    78.21
# 2  2019        32.9  1.56    78.32
# 3  2018        32.5  1.23    76.21
# 4  2017        31.9  1.52    78.12
# 5  2016        31.5  1.35    79.54
# 6  2015        30.9  1.46    78.98
# 7  2010        28.5  1.34    79.24

# %%
df.loc[[1,5]] # DataFramdan aniq bir qatorlarni olishim uchun ishlatiladi
# Out:
#     yil  aholi soni  temp  zichlik
# 1  2020        33.5  1.45    78.21
# 5  2016        31.5  1.35    79.54

# %%
df.loc[[3,6],['yil','temp']] # dataFramdan kerakli qator va ustunlarni ajratib olish uchun ishlatiladi
# Out:
#     yil  temp
# 3  2018  1.23
# 6  2015  1.46

# %%
df.iloc[[1,5]] # DataFramdan aniq bir indexlarni olishim uchun ishlatiladi
# Out:
#     yil  aholi soni  temp  zichlik
# 1  2020        33.5  1.45    78.21
# 5  2016        31.5  1.35    79.54

# %%
df.iloc[[3,6],[0,3]] # dataFramdan kerakli qator va ustun indexlarni ajratib olish uchun ishlatiladi
# Out:
#     yil  zichlik
# 3  2018    76.21
# 6  2015    78.98

# %%
df.at[5,'temp'] # malum bir kordinatadagi qiymatni olish uchun ishlatiladi
# Out:
# 1.35

# %%
df.at[5,'temp'] + df.at[5,'temp']
# Out:
# 2.7

# %%
df.iat[2,2] # DataFremeni index boyicha aniq qiymatini olish
# Out:
# 1.56
