# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns # agar o`rnatilmagan bolsa pip install seaborn

# %%
df = pd.read_csv('https://github.com/anvarnarz/praktikum_datasets/raw/main/museum_visitors.csv', index_col=0)
df.head()
# df.shape
# Out:
#             Avila Adobe  Firehouse Museum  Chinese American Museum  \
# Date
# 2014-01-01        24778              4486                     1581
# 2014-02-01        18976              4172                     1785
# 2014-03-01        25231              7082                     3229
# 2014-04-01        26989              6756                     2129
# 2014-05-01        36883             10858                     3676
#
#             America Tropical Interpretive Center
# Date
# 2014-01-01                                  6602
# 2014-02-01                                  5029
# 2014-03-01                                  8129
# 2014-04-01                                  2824
# 2014-05-01                                 10694

# %%
sns.lineplot(data=df) # chiziqli grafiklar chizishimiz uchun
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.title('Muzaylarga tashriflar')
plt.xlabel('Sana')
plt.ylabel('Odamlar soni')
plt.xticks(rotation=90) # bunda x o`qidagi qiymatlar usma ust bolib qolsa orasini ocish uchun ishlatiladi
plt.grid()
# sns.lineplot(data=df) # dfning barcha qiymatlari boyicha chizadi
sns.lineplot(data=df['America Tropical Interpretive Center']) # malun mir qiyamti boyicha chizishi munkun
plt.show()
